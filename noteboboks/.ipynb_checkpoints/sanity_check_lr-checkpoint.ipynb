# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    roc_auc_score,
    roc_curve,
    precision_recall_curve
)

# 1. Load data
df = pd.read_csv(
    r'C:\Users\ghkjs\GitHub\regime-shift-classification\data\processed\inflation_regime_dataset.csv',
    index_col=0,
    parse_dates=True
)

# 2. Hold out the last 36 months for testing
cutoff = df.index.max() - pd.DateOffset(months=36)
df_train = df.loc[:cutoff]
df_test  = df.loc[cutoff + pd.DateOffset(months=1):]

# 3. Prepare features & target, drop the Z-score shortcut
X_train = df_train.drop(columns=['Inflation_Regime', 'Zscore'])
y_train = df_train['Inflation_Regime']
X_test  = df_test.drop(columns=['Inflation_Regime', 'Zscore'])
y_test  = df_test['Inflation_Regime']

# 4. Build pipeline with class_weight='balanced'
pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler',  StandardScaler()),
    ('clf',     LogisticRegression(
        C=100,
        penalty='l2',
        solver='saga',
        class_weight='balanced',
        max_iter=2000
    ))
])

# 5. Fit on training data
pipeline.fit(X_train, y_train)

# 6. Get raw probabilities
y_prob_train = pipeline.predict_proba(X_train)[:, 1]
y_prob_test  = pipeline.predict_proba(X_test)[:, 1]

# 7. Evaluate with default 0.5 threshold
y_pred_def = (y_prob_test > 0.5).astype(int)
print("=== Default Threshold (0.5) Evaluation ===")
print(classification_report(y_test, y_pred_def))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_def))
print(f"ROC AUC: {roc_auc_score(y_test, y_prob_test):.3f}\n")

# 8. Tune threshold on the training set
prec, rec, thr = precision_recall_curve(y_train, y_prob_train)
f1_scores = 2 * prec * rec / (prec + rec + 1e-8)
best_idx   = np.argmax(f1_scores)
best_thresh = thr[best_idx]
print(f"Best training-set F1 = {f1_scores[best_idx]:.2f} at threshold = {best_thresh:.2f}\n")

# 9. Evaluate with optimized threshold on test
y_pred_opt = (y_prob_test > best_thresh).astype(int)
print("=== Optimized Threshold Evaluation ===")
print(classification_report(y_test, y_pred_opt))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_opt))
print(f"ROC AUC: {roc_auc_score(y_test, y_prob_test):.3f}\n")

# 10. Plot ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_prob_test)
plt.figure(figsize=(6,6))
plt.plot(fpr, tpr, label=f'AUC = {roc_auc_score(y_test, y_prob_test):.3f}')
plt.plot([0,1],[0,1],'--', linewidth=1)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()

# 11. Plot Precision–Recall Curve (showing chosen threshold)
plt.figure(figsize=(6,6))
plt.plot(rec, prec, label="PR curve")
plt.scatter(rec[best_idx], prec[best_idx],
            color='red', label=f'Best F1@{best_thresh:.2f}')
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision–Recall Curve")
plt.legend(loc='lower left')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# === Default Threshold (0.5) Evaluation ===
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        28
#            1       0.22      1.00      0.36         8
#
#     accuracy                           0.22        36
#    macro avg       0.11      0.50      0.18        36
# weighted avg       0.05      0.22      0.08        36
#
# Confusion Matrix:
#  [[ 0 28]
#  [ 0  8]]
# ROC AUC: 1.000
#
# Best training-set F1 = 0.60 at threshold = 0.42
#
# === Optimized Threshold Evaluation ===
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        28
#            1       0.22      1.00      0.36         8
#
#     accuracy                           0.22        36
#    macro avg       0.11      0.50      0.18        36
# weighted avg       0.05      0.22      0.08        36
#
# Confusion Matrix:
#  [[ 0 28]
#  [ 0  8]]
# ROC AUC: 1.000
# C:\Users\ghkjs\anaconda3\envs\econ_trend\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\ghkjs\anaconda3\envs\econ_trend\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\ghkjs\anaconda3\envs\econ_trend\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\ghkjs\anaconda3\envs\econ_trend\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\ghkjs\anaconda3\envs\econ_trend\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\ghkjs\anaconda3\envs\econ_trend\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
